# %%
import numpy as np
from scipy.optimize import minimize

# %%
class Ingredients:
    def __init__(self,name,calorie,tanbal,tansuhamool,protein,fat,calcium,kalium,natrium,vitamin,mg,fe):
        self.kalium=kalium
        self.natrium=natrium
        self.mg=mg
        self.name=name
        self.calorie=calorie
        self.tanbal=tanbal
        self.fat=fat
        self.protein=protein
        self.tansuhamool=tansuhamool
        self.calcium=calcium
        self.fe=fe
        self.vitamin=vitamin

# %%
rice =Ingredients('rice',1.3,2.66,0.28,0.027,0.003,0.0001,0.00035,0.00001,0,0.00012,0.000002)
bori =Ingredients('bori',3.54,0.49,0.00073,0.12,0.023,0.00033,0.00452,0.00012,0,0.00133,0.000054,)
wheat=Ingredients('wheat',3.4,0.51,0.72,0.132,0.025,0.00034,0.00363,0.00002,0,0.00137,0.000036)
corn=Ingredients('corn',0.85,0.63,0.19,0.032,0.012,0.00002,0.0027,0.00015,0.000068,0.00037,0.000005)
cow=Ingredients('cow',2.5,28.73,0,0.26,0.15,0.00018,0.00318,0.00072,0,0.00021,0.00026)
pig=Ingredients('pig',2.42,5.85,0,0.27,0.14,0.00019,0.00423,0.00062,0.000006,0.00028,0.000009)
chicken=Ingredients('chicken',2.39,4.12,0,0.27,0.14,0.00015,0.00223,0.00082,0,0.00023,0.000013)
ori=Ingredients('ori',3.37,9.87,0,0.19,0.28,0.00011,0.00204,0.00059,0,0.00016,0.000027)
tofu=Ingredients('tofu',0.76,3.16,0.019,0.08,0.048,0.0035,0.00121,0.00007,0.000001,0.0003,0.000054)
redbean=Ingredients('redbean',3.29,2,0.63,0.2,0.005,0.00066,0.01254,0.00005,0,0.00127,0.00005)
pea=Ingredients('pea',0.81,0.6,0.14,0.05,0.004,0.00025,0.00244,0.00005,0.0004,0.00033,0.000015)
milk=Ingredients('milk',0.42,1.39,0.05,0.034,0.01,0.00125,0.0015,0.00044,0,0.00011,0)
butter=Ingredients('butter',7.16,11.52,0.001,0.009,0.81,0.00024,0.00024,0.00011,0,0.00002,0)
cheese=Ingredients('cheese',4.05,8.86,0.013,0.25,0.33,0.00721,0.0098,0.00621,0,0.00028,0.000007)
egg=Ingredients('egg',1.55,3.39,0.011,0.13,0.11,0.0005,0.00126,0.00124,0,0.0001,0.000012)
chub_mackerel=Ingredients('chub_mackerel',3.05,2,0,0.19,0.25,0.00066,0.0052,0.0445,0,0.0006,0.000014)
squid=Ingredients('squid',0.92,8.07,0.031,0.156,0.014,0.00032,0.00246,0.00044,0.000047,0.00033,0.000007)
shrimp=Ingredients('shrimp',0.85,14.85,0,0.2,0.001,0.00064,0.00264,0.00119,0.00002,0.00035,0.000005)
salmon=Ingredients('salmon',1.2,4.14,0,0.2,0.038,0.00011,0.00429,0.0005,0,0.00022,0.000006)
hairtail=Ingredients('hairtail',2.66,5.631,0,0.165,0.209,0.00012,0.0029,0.00088,0.00001,0.00029,0.000002)
abalone=Ingredients('abalone',0.73,0.0441,0.04,0.127,0.003,0.0002,0.002,0.0033,0.00001,0.00054,0.000015)
                  'watermelon':watermelon,'mandarin':mandarin,'peach':peach,'oriental_orange': oriental_orange,
                  'strawberry':strawberry,'orange':orange,'banana':banana,'grape':grape,'tomato':tomato,'cucumber':cucumber,
                   'cherry':cherry,'pear':pear,'moo':moo,'cabbage':cabbage,'garlic':garlic,'onion':onion,
                    'chili':chili,'lettuce':lettuce,'perilla_leaf':perilla_leaf,'brocoli':brocoli,'eggplant':eggplant,
                    'salary':salary,'beansprouts':beansprouts,'potato':potato,'sweetpotato':sweetpotato,'peanut':peanut,
                    'walnut':walnut,'oatmeal':oatmeal,'almond':almond}

# %%
# input값을 자기가 원하는 걸로 설정할때의 코드


def first_insertion():
    name=input("What's your name?:")
    age=input("What's your age?")
    gender=input("What's your gender?: male female")
    if gender== 'male':
        if 1<=age<=5: 
            default_calorie=1150
            default_protein=22.5
            
        elif 6<=age<=8:
            default_calorie=1700
            default_protein=35
        elif 9<=age<=11:
            default_calorie=2000
            default_protein=50
        elif 12<=age<=14:
            default_calorie=2500
            default_protein=60
        elif 15<=age<=18:
            default_calorie=2700
            default_protein=65
        elif 19<=age<=29:
            default_calorie=2600
            default_protein=65
        elif 30<=age<=49:
            default_calorie=2500
            default_protein=65
        elif 50<=age<=64:
            default_calorie=2200
            default_protein=60
        elif 65<=age<=74:
            default_calorie=2000
            default_protein=60
        else:
            default_calorie=1900
            default_protein=60
    elif gender=='female':
        if 1<=age<=5: 
            default_calorie=1150
            default_protein=22.5
        elif 6<=age<=8:
            default_calorie=1500
            default_protein=35
        elif 9<=age<=11:
            default_calorie=1800
            default_protein=45
        elif 12<=age<=14:
            default_calorie=2000
            default_protein=55
        elif 15<=age<=18:
            default_calorie=2000
            default_protein=55
        elif 19<=age<=29:
            default_calorie=2000
            default_protein=55
        elif 30<=age<=49:
            default_calorie=1900
            default_protein=50
        elif 50<=age<=64:
            default_calorie=1700
            default_protein=50
        elif 65<=age<=74:
            default_calorie=1600
            default_protein=50
        else:
            default_calorie=1500
            default_protein=50
    default_fat=default_calorie*0.03
    

    
    
def food_choice() :

    while (chance==0):
        x=input('''choose your ingredient: 
            1.rice
            2.bori
            3.wheat
            4.corn
            5.cow
            6.pig
            7.chicken
            8.ori
            9.tofu
            10.redbean
            11.pea
            12.milk
            13.butter
            14.cheese
            15.egg
            16.chub_mackerel
            17.squid
            18.shrimp
            19.salmon
            20.hairtail
            21.abalone
            22.tuna
            23.pollak
            24.halibut
            25.anchovy
            26.oyster
            27.webfoot
            28.small_octopus
            29.laver
            30.seaweed
            31.kelp
            32.apple
            33.watermelon
            34.mandarin
            35.peach
            36.oriental_orange
            37.strawberry
            38.orange
            39.banana
            40.grape
            41.tomato
            42.cucumber
            43.cherry
            44.pear
            45.moo
            46.cabbage
            47.garlic
            48.onion
            49.chili
            50.lettuce
            51.perilla_leaf
            52.brocoli
            53.eggplant
            54.salary
            55.beansprouts
            56.potato
            57.sweetpotato
            58.peanut
            59.walnut
            60.oatmeal
            61.almond
           
            
            
            
            
            ///if you finish enter 0!!!''').lower()
    
        if x=='0':
            chance=11
        else:
            new1=ingredients_list[x]
            chooselist.append(new1)

# %%
global tansoresult
global calorieresult
global proteinresult
global tansuhamoolresult
global fatresult


def objective_func_tanso(x):
    
    tansoresult=0
    for i in range(0,importantlength):
        tansoresult+=chooselist[i].tanbal*x[i]
    return tansoresult

def inequality_constraint_calori(x):
    calorieresult=0
    for i in range(0,importantlength):
        calorieresult+=chooselist[i].calorie*x[i]
    return -calorieresult+default_calorie*1.1

def inequality_constraint_calori2(x):
    calorieresult=0
    for i in range(0,importantlength):
        calorieresult+=chooselist[i].calorie*x[i]
    return calorieresult-default_calorie*0.9

def inequality_constraint_protein(x):
    proteinresult=0
    for i in range(0,importantlength):
        proteinresult+=chooselist[i].protein*x[i]
    return -proteinresult+default_protein*1.1

def inequality_constraint_protein2(x):
    proteinresult=0
    for i in range(0,importantlength):
        proteinresult+=chooselist[i].protein*x[i]
    return proteinresult-default_protein*0.9
    
def inequality_constraint_tansuhamool(x):
    tansuhamoolresult=0
    for i in range(0,importantlength):
        tansuhamoolresult+=chooselist[i].tansuhamool*x[i]
    return -tansuhamoolresult+130*1.1

def inequality_constraint_tansuhamool2(x):
    tansuhamoolresult=0
    for i in range(0,importantlength):
        tansuhamoolresult+=chooselist[i].tansuhamool*x[i]
    return tansuhamoolresult-130*0.9

def inequality_constraint_fat(x):
    fatresult=0
    for i in range(0,importantlength):
        fatresult+=chooselist[i].fat*x[i]
    return -fatresult+default_fat

def inequality_constraint_fat2(x):
    fatresult=0
    for i in range(0,importantlength):
        fatresult+=chooselist[i].fat*x[i]
    return fatresult-0

def please(chooselist):
    
    constraint1={'type':'ineq','fun':inequality_constraint_calori}
    constraint2={'type':'ineq','fun':inequality_constraint_calori2}
   
    constraint7={'type':'ineq','fun':inequality_constraint_fat}
    constraint8={'type':'ineq','fun':inequality_constraint_fat2}

    constraint11={'type':'ineq','fun':inequality_constraint_tansuhamool}
    constraint12={'type':'ineq','fun':inequality_constraint_tansuhamool2}
    constraint13={'type':'ineq','fun':inequality_constraint_protein}
    constraint14={'type':'ineq','fun':inequality_constraint_protein2}



    constraint=[constraint1,constraint2,constraint7,constraint8,constraint11,constraint12,constraint13,constraint14]
    bounds=[]
    x0=[]
    for i in range(0,importantlength):
        limit=(100,600)
        bounds.append(limit)
        x0.append(100)
    results=minimize(objective_func_tanso,x0, method="SLSQP",bounds=bounds,constraints=constraint)
    
    if results.success==True:
        for i in range(0,importantlength):
            print(f"{chooselist[i].name} : {round(results.x[i])}" )
        
    else:
        print("We need other ingredients that could make our model fit")

#constraint=[constraint2,constraint4,constraint6,constraint8,constraint10,constraint12,constraint14,constraint16,constraint18,constraint20]
#음식 세개가 최소 100g은 넘어야한다고 설정 최대 200g

# %%
chooselist=[]
chance=0
first_insertion()
food_choice()
importantlength=len(chooselist)

please(chooselist)
# Out:
# What's your name?:chaerin
